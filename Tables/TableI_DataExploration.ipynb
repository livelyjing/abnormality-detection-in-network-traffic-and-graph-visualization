# %%
import pandas as pd
import numpy as np
from math import floor
import numpy as np

rawDataFrame = pd.read_csv('/Users/emmap/Downloads/TrafficLabelling/Monday-WorkingHours.pcap_ISCX.csv')

rawDataFrame = rawDataFrame.drop(rawDataFrame[pd.isnull(rawDataFrame['Flow ID'])].index)
rawDataFrame.replace('Infinity', -1, inplace=True)
rawDataFrame.replace([np.inf, -np.inf, np.nan], -1, inplace=True)
rawDataFrame[['Flow Bytes/s', ' Flow Packets/s']] = rawDataFrame[['Flow Bytes/s',' Flow Packets/s']].apply(pd.to_numeric)
    
rawDataFrame = rawDataFrame.loc[rawDataFrame['Flow Bytes/s'] > 0]
rawDataFrame = rawDataFrame.loc[rawDataFrame[' Flow Packets/s'] > 0]
rawDataFrame = rawDataFrame.loc[rawDataFrame[' Flow Duration'] > 0]

total_df = len(rawDataFrame.index)
print(f'Total Mon {total_df}')

attack_df = rawDataFrame.loc[rawDataFrame[' Label'] != "BENIGN"]
attack_total = len(attack_df.index)
print(f'Attack Mon {attack_total}')


normal_df = rawDataFrame.loc[rawDataFrame[' Label'] == "BENIGN"]
normal_total = len(normal_df.index)
print(f'Normal Mon {normal_total}')

# %%
import pandas as pd
import numpy as np
from math import floor
import numpy as np

rawDataFrame = pd.read_csv('/Users/emmap/Downloads/TrafficLabelling/Tuesday-WorkingHours.pcap_ISCX.csv')

rawDataFrame = rawDataFrame.drop(rawDataFrame[pd.isnull(rawDataFrame['Flow ID'])].index)
rawDataFrame.replace('Infinity', -1, inplace=True)
rawDataFrame.replace([np.inf, -np.inf, np.nan], -1, inplace=True)
rawDataFrame[['Flow Bytes/s', ' Flow Packets/s']] = rawDataFrame[['Flow Bytes/s',' Flow Packets/s']].apply(pd.to_numeric)
    
rawDataFrame = rawDataFrame.loc[rawDataFrame['Flow Bytes/s'] > 0]
rawDataFrame = rawDataFrame.loc[rawDataFrame[' Flow Packets/s'] > 0]
rawDataFrame = rawDataFrame.loc[rawDataFrame[' Flow Duration'] > 0]

vars = [' Flow Duration', ' Flow Packets/s', 'Flow Bytes/s']
for var in vars:    
    print(f'[{var}] Min: {rawDataFrame[var].min()}', end="; ")
    print(f'Max: {rawDataFrame[var].max()}', end="; ")
    print(f'Mean: {rawDataFrame[var].mean()}', end="; ")
    print(f'Median: {rawDataFrame[var].median()}', end="; ")
    print(f'Standard Deviation: {rawDataFrame[var].std()}')

total_df = len(rawDataFrame.index)
print(f'Total Tue {total_df}')

attack_df = rawDataFrame.loc[rawDataFrame[' Label'] != "BENIGN"]
attack_total = len(attack_df.index)
print(f'Attack Tue {attack_total}')

normal_df = rawDataFrame.loc[rawDataFrame[' Label'] == "BENIGN"]
normal_total = len(normal_df.index)
print(f'Normal Tue {normal_total}')

# %%
import pandas as pd
import numpy as np
from math import floor
import numpy as np

rawDataFrame = pd.read_csv('/Users/emmap/Downloads/TrafficLabelling/Wednesday-WorkingHours.pcap_ISCX.csv')

rawDataFrame = rawDataFrame.drop(rawDataFrame[pd.isnull(rawDataFrame['Flow ID'])].index)
rawDataFrame.replace('Infinity', -1, inplace=True)
rawDataFrame.replace([np.inf, -np.inf, np.nan], -1, inplace=True)
rawDataFrame[['Flow Bytes/s', ' Flow Packets/s']] = rawDataFrame[['Flow Bytes/s',' Flow Packets/s']].apply(pd.to_numeric)
    
rawDataFrame = rawDataFrame.loc[rawDataFrame['Flow Bytes/s'] > 0]
rawDataFrame = rawDataFrame.loc[rawDataFrame[' Flow Packets/s'] > 0]
rawDataFrame = rawDataFrame.loc[rawDataFrame[' Flow Duration'] > 0]

total_df = len(rawDataFrame.index)
print(f'Total Wed {total_df}')

attack_df = rawDataFrame.loc[rawDataFrame[' Label'] != "BENIGN"]
attack_total = len(attack_df.index)
print(f'Attack Wed {attack_total}')

normal_df = rawDataFrame.loc[rawDataFrame[' Label'] == "BENIGN"]
normal_total = len(normal_df.index)
print(f'Normal Wed {normal_total}')

# %%
import pandas as pd
import numpy as np
from math import floor
import numpy as np

rawDataFrame = pd.read_csv('/Users/emmap/Downloads/TrafficLabelling/Thursday-WorkingHours-Morning-WebAttacks.pcap_ISCX.csv')

rawDataFrame = rawDataFrame.drop(rawDataFrame[pd.isnull(rawDataFrame['Flow ID'])].index)
rawDataFrame.replace('Infinity', -1, inplace=True)
rawDataFrame.replace([np.inf, -np.inf, np.nan], -1, inplace=True)
rawDataFrame[['Flow Bytes/s', ' Flow Packets/s']] = rawDataFrame[['Flow Bytes/s',' Flow Packets/s']].apply(pd.to_numeric)
    
rawDataFrame = rawDataFrame.loc[rawDataFrame['Flow Bytes/s'] > 0]
rawDataFrame = rawDataFrame.loc[rawDataFrame[' Flow Packets/s'] > 0]
rawDataFrame = rawDataFrame.loc[rawDataFrame[' Flow Duration'] > 0]

total_df = len(rawDataFrame.index)
print(f'Total Thu morning {total_df}')

attack_df = rawDataFrame.loc[rawDataFrame[' Label'] != "BENIGN"]
attack_total = len(attack_df.index)
print(f'Attack Thu morning {attack_total}')


normal_df = rawDataFrame.loc[rawDataFrame[' Label'] == "BENIGN"]
normal_total = len(normal_df.index)
print(f'Normal Thu morning {normal_total}')

# %%
import pandas as pd
import numpy as np
from math import floor
import numpy as np

rawDataFrame = pd.read_csv('/Users/emmap/Downloads/TrafficLabelling/Thursday-WorkingHours-Afternoon-Infilteration.pcap_ISCX.csv')

rawDataFrame = rawDataFrame.drop(rawDataFrame[pd.isnull(rawDataFrame['Flow ID'])].index)
rawDataFrame.replace('Infinity', -1, inplace=True)
rawDataFrame.replace([np.inf, -np.inf, np.nan], -1, inplace=True)
rawDataFrame[['Flow Bytes/s', ' Flow Packets/s']] = rawDataFrame[['Flow Bytes/s',' Flow Packets/s']].apply(pd.to_numeric)
    
rawDataFrame = rawDataFrame.loc[rawDataFrame['Flow Bytes/s'] > 0]
rawDataFrame = rawDataFrame.loc[rawDataFrame[' Flow Packets/s'] > 0]
rawDataFrame = rawDataFrame.loc[rawDataFrame[' Flow Duration'] > 0]

total_df = len(rawDataFrame.index)
print(f'Total Thu afternoon {total_df}')

attack_df = rawDataFrame.loc[rawDataFrame[' Label'] != "BENIGN"]
attack_total = len(attack_df.index)
print(f'Attack Thu afternoon {attack_total}')

normal_df = rawDataFrame.loc[rawDataFrame[' Label'] == "BENIGN"]
normal_total = len(normal_df.index)
print(f'Normal Thu afternoon {normal_total}')

# %%
import pandas as pd
import numpy as np
from math import floor
import numpy as np

rawDataFrame = pd.read_csv('/Users/emmap/Downloads/TrafficLabelling/Friday-WorkingHours-Morning.pcap_ISCX.csv')

rawDataFrame = rawDataFrame.drop(rawDataFrame[pd.isnull(rawDataFrame['Flow ID'])].index)
rawDataFrame.replace('Infinity', -1, inplace=True)
rawDataFrame.replace([np.inf, -np.inf, np.nan], -1, inplace=True)
rawDataFrame[['Flow Bytes/s', ' Flow Packets/s']] = rawDataFrame[['Flow Bytes/s',' Flow Packets/s']].apply(pd.to_numeric)
    
rawDataFrame = rawDataFrame.loc[rawDataFrame['Flow Bytes/s'] > 0]
rawDataFrame = rawDataFrame.loc[rawDataFrame[' Flow Packets/s'] > 0]
rawDataFrame = rawDataFrame.loc[rawDataFrame[' Flow Duration'] > 0]

vars = [' Flow Duration', ' Flow Packets/s', 'Flow Bytes/s']
for var in vars:    
    print(f'[{var}] Min: {rawDataFrame[var].min()}', end="; ")
    print(f'Max: {rawDataFrame[var].max()}', end="; ")
    print(f'Mean: {rawDataFrame[var].mean()}', end="; ")
    print(f'Median: {rawDataFrame[var].median()}', end="; ")
    print(f'Standard Deviation: {rawDataFrame[var].std()}')

total_df = len(rawDataFrame.index)
print(f'Total Fri morning {total_df}')

attack_df = rawDataFrame.loc[rawDataFrame[' Label'] != "BENIGN"]
attack_total = len(attack_df.index)
print(f'Attack Fri morning {attack_total}')

normal_df = rawDataFrame.loc[rawDataFrame[' Label'] == "BENIGN"]
normal_total = len(normal_df.index)
print(f'Normal Fri morning {normal_total}')

# %%
import pandas as pd
import numpy as np
from math import floor
import numpy as np

rawDataFrame = pd.read_csv('/Users/emmap/Downloads/TrafficLabelling/Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv')

rawDataFrame = rawDataFrame.drop(rawDataFrame[pd.isnull(rawDataFrame['Flow ID'])].index)
rawDataFrame.replace('Infinity', -1, inplace=True)
rawDataFrame.replace([np.inf, -np.inf, np.nan], -1, inplace=True)
rawDataFrame[['Flow Bytes/s', ' Flow Packets/s']] = rawDataFrame[['Flow Bytes/s',' Flow Packets/s']].apply(pd.to_numeric)
    
rawDataFrame = rawDataFrame.loc[rawDataFrame['Flow Bytes/s'] > 0]
rawDataFrame = rawDataFrame.loc[rawDataFrame[' Flow Packets/s'] > 0]
rawDataFrame = rawDataFrame.loc[rawDataFrame[' Flow Duration'] > 0]

total_df = len(rawDataFrame.index)
print(f'Total Fri afternoon1 {total_df}')

attack_df = rawDataFrame.loc[rawDataFrame[' Label'] != "BENIGN"]
attack_total = len(attack_df.index)
print(f'Attack Fri afternoon1 {attack_total}')

normal_df = rawDataFrame.loc[rawDataFrame[' Label'] == "BENIGN"]
normal_total = len(normal_df.index)
print(f'Normal Fri afternoon1 {normal_total}')

# %%
import pandas as pd
import numpy as np
from math import floor
import numpy as np

rawDataFrame = pd.read_csv('/Users/emmap/Downloads/TrafficLabelling/Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv')

rawDataFrame = rawDataFrame.drop(rawDataFrame[pd.isnull(rawDataFrame['Flow ID'])].index)
rawDataFrame.replace('Infinity', -1, inplace=True)
rawDataFrame.replace([np.inf, -np.inf, np.nan], -1, inplace=True)
rawDataFrame[['Flow Bytes/s', ' Flow Packets/s']] = rawDataFrame[['Flow Bytes/s',' Flow Packets/s']].apply(pd.to_numeric)
    
rawDataFrame = rawDataFrame.loc[rawDataFrame['Flow Bytes/s'] > 0]
rawDataFrame = rawDataFrame.loc[rawDataFrame[' Flow Packets/s'] > 0]
rawDataFrame = rawDataFrame.loc[rawDataFrame[' Flow Duration'] > 0]

total_df = len(rawDataFrame.index)
print(f'Total Fri afternoon2 {total_df}')

attack_df = rawDataFrame.loc[rawDataFrame[' Label'] != "BENIGN"]
attack_total = len(attack_df.index)
print(f'Attack Fri afternoon2 {attack_total}')

normal_df = rawDataFrame.loc[rawDataFrame[' Label'] == "BENIGN"]
normal_total = len(normal_df.index)
print(f'Normal Fri afternoon2 {normal_total}')
